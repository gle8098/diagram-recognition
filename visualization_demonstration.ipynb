# %%
from src.visualizer import Visualizer
import glob
from matplotlib import pyplot as plt
import cv2

path = 'data/images/d_3/board-1.sgf'
visualizer = Visualizer(path)
img_path = 'data/images/d_3.png'
img_files = glob.glob(img_path)
for img_file in img_files:
    img = cv2.imread(img_file)
visualizer.draw_board(img)

# %%
path = 'data/boards/min_board.sgf'
visualizer = Visualizer(path)
visualizer.draw_board()

# %%
path = 'data/boards/max_board.sgf'
visualizer = Visualizer(path)
visualizer.draw_board()

# %%
paths = ['data/images/pages/chinese/1000_TsumeGo-10/*']
for path in paths:
    img_files = glob.glob(path)
    for img_file in img_files:
        print(img_file)
        visualizer = Visualizer(img_file)
        visualizer.draw_board()
        plt.show()
# Out:
# data/images/pages/chinese/1000_TsumeGo-10\board-1.sgf
# data/images/pages/chinese/1000_TsumeGo-10\board-10.sgf
# data/images/pages/chinese/1000_TsumeGo-10\board-11.sgf
# data/images/pages/chinese/1000_TsumeGo-10\board-12.sgf
# data/images/pages/chinese/1000_TsumeGo-10\board-2.sgf
# data/images/pages/chinese/1000_TsumeGo-10\board-3.sgf
# data/images/pages/chinese/1000_TsumeGo-10\board-4.sgf
# data/images/pages/chinese/1000_TsumeGo-10\board-5.sgf
# data/images/pages/chinese/1000_TsumeGo-10\board-6.sgf
# data/images/pages/chinese/1000_TsumeGo-10\board-7.sgf
# data/images/pages/chinese/1000_TsumeGo-10\board-8.sgf
# data/images/pages/chinese/1000_TsumeGo-10\board-9.sgf

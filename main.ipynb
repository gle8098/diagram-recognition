# %%
import cv2
import glob
from src.board import Board

# %%
path = "data/images/d_2.png"
img = cv2.imread(path, cv2.IMREAD_COLOR)
board = Board(img)
board.visualize()
# board.get_white_coordinates()
# print('___')
# board.get_black_coordinates()
# print(board.intersections)
index = path.rfind('.')
path = path[:index+1] + 'sgf'
board.save_sgf(path)

# %%
# paths = ['data/images/d_2.png']#['data/images/d_*', 'data/images/chinese/*', 'data/images/cho_chikun/*']
# for path in paths:
#     img_files = glob.glob(path)
#     for img_file in img_files:
#         #print(img_file)
#         img = cv2.imread(img_file)
#         board = Board(img)
#         board.visualize()
